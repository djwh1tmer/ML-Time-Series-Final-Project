# %% [markdown]
# # Model Selection and Evaluation - Wheat Pricing Data
# ## Time Series and Machine Learning Final Project Code
# ## Will Bartlett and David Whitmer

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb

# %%
#read df
df = pd.read_csv(r'../Final Data/Final_Data.csv')
wheat_price = pd.read_csv(r'../Cleaned Data/Wheat_Price_FRED_clean.csv')
#add new wheat prie data
wheat_price = wheat_price.rename(columns={"PWHEAMTUSDM": "Wheat_Price"})
df = pd.merge(df, wheat_price[['observation_date', 'Wheat_Price']], left_on='date', right_on='observation_date', how='left').drop(['observation_date','wheat_price'], axis=1).rename(columns={'Wheat_Price': 'wheat_price'})

# %%
#creat log return data
df['date'] = pd.to_datetime(df['date'])
exclude_cols = ['date', 'avg_temp', 'drought_idx']
cols_to_logret = [col for col in df.columns if col not in exclude_cols]
logret_df = df[['date']].copy()
for col in cols_to_logret:
    logret_df[col + '_logret'] = (np.log(df[col]) - np.log(df[col].shift(1)))*100

#add unchanged vars
logret_df['avg_temp'] = df['avg_temp']
logret_df['drought_idx'] = df['drought_idx']
logret_df['wheat_price_logret_future'] = logret_df['wheat_price_logret'].shift(-1)
logret_df = logret_df.dropna()
logret_df =  logret_df.set_index("date")   
logret_df.head()
# Out:
#             fertilizer_idx_logret  cpi_logret  commodity_imp_idx_logret  \
# date
# 1990-02-01               4.862365    0.391390                  0.215983
# 1990-03-01              -0.417189    0.467655                 -0.324149
# 1990-04-01              -0.418937    0.233010                 -0.869571
# 1990-05-01              -2.809891    0.155039                 -0.437637
# 1990-06-01              -2.980063    0.617763                 -0.439561
#
#             commodity_exp_idx_logret  flour_price_logret  corn_price_logret  \
# date
# 1990-02-01                 -0.632247           -1.593659           0.371031
# 1990-03-01                  0.211193            1.197619           3.278994
# 1990-04-01                  0.315956           -0.397615           7.589858
# 1990-05-01                  0.210084            1.188133           2.298939
# 1990-06-01                 -0.210084            1.949379          -0.978787
#
#             crude_oil_price_logret  wheat_price_logret   avg_temp  \
# date
# 1990-02-01               -3.335866           -4.246455  -1.965352
# 1990-03-01               -8.098541           -2.777957   4.222106
# 1990-04-01              -10.106481            1.860522   9.391660
# 1990-05-01               -1.255818           -6.669145  13.738063
# 1990-06-01               -8.601287           -9.555649  19.995775
#
#             drought_idx  wheat_price_logret_future
# date
# 1990-02-01         14.6                  -2.777957
# 1990-03-01         11.2                   1.860522
# 1990-04-01          8.0                  -6.669145
# 1990-05-01          7.1                  -9.555649
# 1990-06-01          7.3                  -8.185102

# %%
#plot correlation heatmap
corr_matrix = logret_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Matrix Heatmap")
plt.savefig('../Visualizations/Correlation_Heatmap.png')
plt.show()

# %%
#create test and train data (train on 1990 - 2018, test on 2018-2025)
logret_df_train_data = logret_df.loc[:'2018-01-01']
logret_df_test_data = logret_df.loc['2018-02-01':]

#run autoregressive model (4 lags)
model_wheat = AutoReg(logret_df_train_data["wheat_price_logret_future"], lags=4,
                      exog= logret_df_train_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit()

#forecast the ar model
forecast_steps = len(logret_df_test_data)
forecast_result = model_wheat.get_prediction(start=len(logret_df_train_data), end=len(logret_df_train_data) + forecast_steps - 1, 
                                              exog_oos = logret_df_test_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']])

forecast_result_mean  = forecast_result.predicted_mean

# Confidence intervals
forecast_result_conf_int = forecast_result.conf_int()
print("Predicted values:\n", forecast_result_mean)
print("Confidence intervals:\n", forecast_result_conf_int)
# Out:
# Predicted values:
#  2018-02-01    2.607461
# 2018-03-01   -0.374686
# 2018-04-01   -0.445377
# 2018-05-01   -0.059316
# 2018-06-01    0.789687
#                 ...
# 2024-08-01   -0.796184
# 2024-09-01   -0.254983
# 2024-10-01   -0.352061
# 2024-11-01    0.603212
# 2024-12-01    0.227903
# Freq: MS, Name: predicted_mean, Length: 83, dtype: float64
# Confidence intervals:
#                  lower      upper
# 2018-02-01 -10.048162  15.263084
# 2018-03-01 -13.421846  12.672474
# 2018-04-01 -13.493786  12.603032
# 2018-05-01 -13.117388  12.998756
# 2018-06-01 -12.283268  13.862641
# ...               ...        ...
# 2024-08-01 -13.871402  12.279034
# 2024-09-01 -13.330201  12.820235
# 2024-10-01 -13.427279  12.723157
# 2024-11-01 -12.472006  13.678430
# 2024-12-01 -12.847315  13.303121
#
# [83 rows x 2 columns]
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)

# %%
# Plot actual vs forecasted values for ar model
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(logret_df_test_data.index, forecast_result_mean, label="Forecast", color="red", linestyle="dashed")
#Plot confidence intervals
plt.fill_between(logret_df_test_data.index, forecast_result_conf_int.lower, forecast_result_conf_int.upper, color="blue", alpha=0.3, label="95% CI")

#Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - AR Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/AR_Predictions.png')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings('ignore')

#find best ARIMA model parameters for full dataset
best_aic = float('inf')
best_order = None

#test for range of (p,d,q) order
for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                #model with exogenous features
                arima_model_wheat = ARIMA(logret_df["wheat_price_logret_future"], order=(p,d,q),
                                          exog= logret_df[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit()
                if arima_model_wheat.aic < best_aic:
                    best_aic = arima_model_wheat.aic
                    best_order = (p, d, q)
            except:
                continue

#print best model results
print(f"Best ARIMA order: {best_order}")
best_arima = ARIMA(logret_df["wheat_price_logret_future"], order = best_order,
                   exog= logret_df[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit()
print('\n',best_arima.summary())
# Out:
# Best ARIMA order: (1, 0, 2)
#
#                                     SARIMAX Results
# =====================================================================================
# Dep. Variable:     wheat_price_logret_future   No. Observations:                  419
# Model:                        ARIMA(1, 0, 2)   Log Likelihood               -1370.513
# Date:                       Mon, 12 May 2025   AIC                           2759.025
# Time:                               11:33:58   BIC                           2795.366
# Sample:                                    0   HQIC                          2773.390
#                                        - 419
# Covariance Type:                         opg
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.9438      0.369     -2.561      0.010      -1.666      -0.221
# corn_price_logret           -0.0462      0.065     -0.708      0.479      -0.174       0.082
# drought_idx                  0.1148      0.043      2.679      0.007       0.031       0.199
# fertilizer_idx_logret        0.1415      0.092      1.542      0.123      -0.038       0.321
# commodity_imp_idx_logret     0.4732      0.276      1.717      0.086      -0.067       1.013
# ar.L1                        0.9349      0.028     32.938      0.000       0.879       0.991
# ma.L1                       -0.7197      0.053    -13.464      0.000      -0.824      -0.615
# ma.L2                       -0.2731      0.047     -5.795      0.000      -0.365      -0.181
# sigma2                      39.6021      2.081     19.034      0.000      35.524      43.680
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                37.79
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.61   Skew:                             0.10
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#run best ARIMA model on training data
arima_train=ARIMA(logret_df_train_data["wheat_price_logret_future"], order = best_order,
                   exog= logret_df_train_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit()
#forecast
arima_forecast = arima_train.get_prediction(start=len(logret_df_train_data), end=len(logret_df_train_data) + forecast_steps - 1, 
                                              exog = logret_df_test_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']])
arima_forecast_result_mean  = arima_forecast.predicted_mean

print("Predicted values:\n", arima_forecast_result_mean)
# Out:
# Predicted values:
#  2018-02-01    3.155446
# 2018-03-01   -0.211028
# 2018-04-01    0.192964
# 2018-05-01    0.359572
# 2018-06-01    1.187275
#                 ...
# 2024-08-01   -1.172696
# 2024-09-01   -0.250114
# 2024-10-01   -0.644754
# 2024-11-01    0.780504
# 2024-12-01   -0.183072
# Freq: MS, Name: predicted_mean, Length: 83, dtype: float64

# %%
#plot ARIMA forecast
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(logret_df_test_data.index, arima_forecast_result_mean, label="Forecast", color="red", linestyle="dashed")

# Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - ARIMA Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/ARIMA_Predictions.png')
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

#find best SARIMAX parameters
best_aic = float('inf')
best_order = None
best_seasonal = None

#test range of (p,d,q) order and range of seasonal (P,D,Q) order
for P in range(2):
    for D in range(2):
        for Q in range(2):
            for p in range(3):
                for d in range(2):
                    for q in range(3):
                        try:
                            #run sarimax model
                            sarimax_model_wheat = SARIMAX(logret_df["wheat_price_logret_future"], order=(p,d,q),seasonal_order=(P, D, Q, 12),
                                          exog= logret_df[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit(disp=False)
                            if sarimax_model_wheat.aic < best_aic:
                                best_aic = sarimax_model_wheat.aic
                                best_order = (p, d, q)
                                best_seasonal = (P,D,Q,12)
                        except:
                            continue

#print best model summary
print(f"Best SARIMAX order: {best_order}x{best_seasonal}")
best_sarimax = SARIMAX(logret_df["wheat_price_logret"], order = best_order,seasonal_order = best_seasonal,
                   exog= logret_df[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit(disp=False)
print('\n',best_sarimax.summary())
# Out:
# Best SARIMAX order: (1, 0, 2)x(1, 1, 1, 12)
#
#                                        SARIMAX Results
# ============================================================================================
# Dep. Variable:                   wheat_price_logret   No. Observations:                  419
# Model:             SARIMAX(1, 0, 2)x(1, 1, [1], 12)   Log Likelihood               -1291.961
# Date:                              Mon, 12 May 2025   AIC                           2603.923
# Time:                                      11:37:23   BIC                           2644.011
# Sample:                                           0   HQIC                          2619.787
#                                               - 419
# Covariance Type:                                opg
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# corn_price_logret            0.6367      0.044     14.582      0.000       0.551       0.722
# drought_idx                  0.0588      0.043      1.380      0.168      -0.025       0.142
# fertilizer_idx_logret       -0.0018      0.074     -0.024      0.981      -0.148       0.144
# commodity_imp_idx_logret     0.0957      0.235      0.408      0.683      -0.364       0.556
# ar.L1                       -0.5214      0.445     -1.171      0.242      -1.394       0.351
# ma.L1                        0.7090      0.448      1.582      0.114      -0.169       1.588
# ma.L2                        0.0397      0.120      0.330      0.741      -0.196       0.276
# ar.S.L12                    -0.0660      0.049     -1.335      0.182      -0.163       0.031
# ma.S.L12                    -0.9275      0.038    -24.330      0.000      -1.002      -0.853
# sigma2                      31.4735      1.946     16.174      0.000      27.660      35.287
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                27.43
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.78   Skew:                            -0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#run best SARIMAX on training data
sarimax_train=SARIMAX(logret_df_train_data["wheat_price_logret_future"], order = best_order,seasonal_order = best_seasonal,
                   exog= logret_df_train_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']]).fit(disp=False)
#forecast
sarimax_forecast = sarimax_train.get_prediction(start=len(logret_df_train_data), end=len(logret_df_train_data) + forecast_steps - 1, 
                                              exog = logret_df_test_data[['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret']])
sarimax_forecast_result_mean  = sarimax_forecast.predicted_mean

print("Predicted values:\n", sarimax_forecast_result_mean)
# Out:
# Predicted values:
#  2018-02-01    3.137997
# 2018-03-01   -0.969338
# 2018-04-01    0.259529
# 2018-05-01   -1.724877
# 2018-06-01   -0.489738
#                 ...
# 2024-08-01   -0.176818
# 2024-09-01    0.657587
# 2024-10-01   -0.429999
# 2024-11-01    2.458719
# 2024-12-01    0.291090
# Freq: MS, Name: predicted_mean, Length: 83, dtype: float64

# %%
#plot predictions and forecast 
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(logret_df_test_data.index, sarimax_forecast_result_mean, label="Forecast", color="red", linestyle="dashed")

# Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - SARIMAX Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/SARIMAX_Predictions.png')
plt.show()

# %%
#add lagged variables for deep learning models

#add extra lags for primary data values
primary_vars = ['corn_price_logret','drought_idx','fertilizer_idx_logret','commodity_imp_idx_logret','wheat_price_logret']
primary_lags = [1, 2, 3, 6, 12]
secondary_vars = ['crude_oil_price_logret', 'flour_price_logret']
secondary_lags = [1, 3, 6]

df_lagged = logret_df.copy()

# Create lags for primary variables
for var in primary_vars:
    for lag in primary_lags:
        df_lagged[f'{var}_lag_{lag}'] = df_lagged[var].shift(lag)

# Create lags for secondary variables
for var in secondary_vars:
    for lag in secondary_lags:
        df_lagged[f'{var}_lag_{lag}'] = df_lagged[var].shift(lag)
        
df_lagged = df_lagged.dropna()

#save month as datapoint
df_lagged['month'] = df_lagged.index.month
#add cyclical features (sin and cos of month)
logret_df['month_sin'] = np.sin(2 * np.pi * logret_df.index.month / 12)
logret_df['month_cos'] = np.cos(2 * np.pi * logret_df.index.month / 12)

df_lagged.head()
# Out:
#             fertilizer_idx_logret  cpi_logret  commodity_imp_idx_logret  \
# date
# 1991-02-01               0.076132    0.074212                 -2.083409
# 1991-03-01              -0.687288    0.000000                  0.000000
# 1991-04-01              -1.700196    0.222305                 -0.845671
# 1991-05-01              -1.808936    0.369413                 -0.212540
# 1991-06-01              -1.923136    0.294551                 -0.640344
#
#             commodity_exp_idx_logret  flour_price_logret  corn_price_logret  \
# date
# 1991-02-01                 -0.103359           -3.758271           0.743488
# 1991-03-01                 -0.310720            0.000000           2.559569
# 1991-04-01                  0.207254            0.847463           1.077216
# 1991-05-01                 -0.207254           -0.847463          -4.164077
# 1991-06-01                 -0.311689            0.847463          -0.590023
#
#             crude_oil_price_logret  wheat_price_logret   avg_temp  \
# date
# 1991-02-01              -20.858496            2.283945   0.704926
# 1991-03-01               -2.872907            4.725289   3.273592
# 1991-04-01                4.567452            1.223253   9.166041
# 1991-05-01                1.902102            0.946878  14.906199
# 1991-06-01               -5.022784           -1.556634  19.369806
#
#             drought_idx  ...  wheat_price_logret_lag_3  \
# date                     ...
# 1991-02-01         15.7  ...                 -1.615535
# 1991-03-01          8.2  ...                  0.325192
# 1991-04-01          3.8  ...                 -1.636689
# 1991-05-01          1.8  ...                  2.283945
# 1991-06-01          1.4  ...                  4.725289
#
#             wheat_price_logret_lag_6  wheat_price_logret_lag_12  \
# date
# 1991-02-01                 -6.689433                  -4.246455
# 1991-03-01                 -2.225836                  -2.777957
# 1991-04-01                  0.321023                   1.860522
# 1991-05-01                 -1.615535                  -6.669145
# 1991-06-01                  0.325192                  -9.555649
#
#             crude_oil_price_logret_lag_1  crude_oil_price_logret_lag_3  \
# date
# 1991-02-01                     -7.812007                    -10.863384
# 1991-03-01                    -20.858496                    -16.984176
# 1991-04-01                     -2.872907                     -7.812007
# 1991-05-01                      4.567452                    -20.858496
# 1991-06-01                      1.902102                     -2.872907
#
#             crude_oil_price_logret_lag_6  flour_price_logret_lag_1  \
# date
# 1991-02-01                     39.218856                  3.333642
# 1991-03-01                     20.459097                 -3.758271
# 1991-04-01                      7.278553                  0.000000
# 1991-05-01                    -10.863384                  0.847463
# 1991-06-01                    -16.984176                 -0.847463
#
#             flour_price_logret_lag_3  flour_price_logret_lag_6  month
# date
# 1991-02-01                 -3.758271                 -1.941809      2
# 1991-03-01                  0.424629                 -2.381065      3
# 1991-04-01                  3.333642                 -2.028467      4
# 1991-05-01                 -3.758271                 -3.758271      5
# 1991-06-01                  0.000000                  0.424629      6
#
# [5 rows x 43 columns]

# %%
#save train and test set for lagged data
lagged_df_train = logret_df.loc[:'2018-01-01']

lagged_df_test = logret_df.loc['2018-02-01':]

X_train = lagged_df_train.drop(columns='wheat_price_logret_future')
X_test = lagged_df_test.drop(columns='wheat_price_logret_future')
y_train = lagged_df_train['wheat_price_logret_future']
y_test = lagged_df_test['wheat_price_logret_future']

# %%
from sklearn.tree import DecisionTreeRegressor
#run basic DT model
dt_model = DecisionTreeRegressor(max_depth=5, random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
#forecast for DT model
dt_forecast = dt_model.predict(X_test)
dt_forecast_series = pd.Series(dt_forecast, index=X_test.index, name='forecast')

# %%
#plot DT predictions 
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(logret_df_test_data.index, dt_forecast_series, label="Forecast", color="red", linestyle="dashed")

# Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - Basic Decision Tree Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/DT_Predictions.png')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from xgboost import XGBRegressor

#Hyperparameter tune for XGBoost model using gridsearch
tscv = TimeSeriesSplit(n_splits=5)

#Define parameter grid to search
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [50, 100, 200],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42) #initialize

#grid search
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=1,
    n_jobs=-1
).fit(X_train,y_train)

#find and print best params
best_params = grid_search.best_params_
print(f"Best parameters found: {best_params}")
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# Best parameters found: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.9}

# %%
#initialize best model
best_xgb = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    **best_params
)
best_xgb.fit(X_train, y_train)

#Make predictions for XGBoost
xgb_forecast = best_xgb.predict(X_test)
xgb_forecast_series = pd.Series(xgb_forecast, index=X_test.index, name='forecast')

# %%
#plot XGBoost predictions 
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(logret_df_test_data.index, xgb_forecast_series, label="Forecast", color="red", linestyle="dashed")

# Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - XGBoost Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/XGBoost_Predictions.png')
plt.show()

# %%
#print feature importance (top 10)
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': best_xgb.feature_importances_
}).sort_values('Importance', ascending=False).head(10)
print("\nTop 10 Most Important Features:")
print(feature_importance)
# Out:
# Top 10 Most Important Features:
#                      Feature  Importance
# 7         wheat_price_logret    0.154978
# 11                 month_cos    0.117028
# 8                   avg_temp    0.104079
# 3   commodity_exp_idx_logret    0.100259
# 2   commodity_imp_idx_logret    0.090086
# 9                drought_idx    0.083007
# 6     crude_oil_price_logret    0.074612
# 5          corn_price_logret    0.067896
# 4         flour_price_logret    0.059365
# 1                 cpi_logret    0.052933

# %%
#test LSTM model
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from statsmodels.tsa.vector_ar.var_model import VAR

#save features needed
lstm_features = ['wheat_price_logret', 'corn_price_logret', 'drought_idx', 
                'fertilizer_idx_logret', 'commodity_imp_idx_logret', 
                'commodity_exp_idx_logret', 'crude_oil_price_logret',
                'avg_temp', 'month_sin', 'month_cos']
lstm_data = logret_df[lstm_features + ['wheat_price_logret_future']].copy()

#scale data
scaler = MinMaxScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(lstm_data), 
                          columns=lstm_data.columns, 
                          index=lstm_data.index)

# %%
#prep LSTM model
sequence_length = 12
train_data = scaled_data.loc[:'2018-01-01']
test_data = scaled_data.loc['2018-02-01':]

#Create sequences for LSTM
X_train, y_train = [], []
for i in range(len(train_data) - sequence_length):
    X_train.append(train_data.iloc[i:(i + sequence_length)].values)
    #Get target value (next month's wheat price log return)
    y_train.append(train_data.iloc[i + sequence_length]['wheat_price_logret_future'])

X_test, y_test = [], []
for i in range(len(test_data) - sequence_length):
    X_test.append(test_data.iloc[i:(i + sequence_length)].values)
    y_test.append(test_data.iloc[i + sequence_length]['wheat_price_logret_future'])
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
#Hyperparameter tune LSTM model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow import keras

#list of params
lstm_units = [50, 75, 100]
dropout_rates = [0.2, 0.3]
learning_rates = [0.001, 0.0005]

results = []
best_rmse = float('inf')
best_model = None
best_params = None

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

#search for best model
for units in lstm_units:
    for dropout in dropout_rates:
        for lr in learning_rates:
            print(f"Training with: units={units}, dropout={dropout}, learning_rate={lr}")
            
            #Build model
            model = Sequential()
            model.add(keras.layers.LSTM(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
            model.add(keras.layers.LSTM(units, return_sequences=False))
            model.add(keras.layers.Dense(128,activation='relu'))
            model.add(keras.layers.Dropout(dropout))
            model.add(keras.layers.Dense(1))
            
            
            #Compile model
            model.compile(optimizer=Adam(learning_rate=lr), loss='mse')
            
            #Train model
            history = model.fit(
                X_train, y_train,
                epochs=100,
                batch_size=32,
                validation_split=0.2,
                callbacks=[early_stop],
                verbose=1
            )
            
            #Predict
            y_pred = model.predict(X_test)
            
            # Calculate RMSE
            dummy = np.zeros((len(y_pred), len(lstm_features) + 1))
            dummy[:, -1] = y_pred.flatten()
            y_pred_original = scaler.inverse_transform(dummy)[:, -1]
            dummy = np.zeros((len(y_test), len(lstm_features) + 1))
            dummy[:, -1] = y_test
            y_test_original = scaler.inverse_transform(dummy)[:, -1]
            rmse = np.sqrt(mean_squared_error(y_test_original, y_pred_original))
            mae = mean_absolute_error(y_test_original, y_pred_original)
            
            #Store results
            result = {
                'units': units,
                'dropout': dropout,
                'learning_rate': lr,
                'rmse': rmse,
                'mae': mae,
                'final_val_loss': history.history['val_loss'][-1],
                'epochs_used': len(history.history['loss'])
            }
            results.append(result)

            # Check if this is the best model
            if rmse < best_rmse:
                best_rmse = rmse
                best_model = model
                best_params = result
                print("New best model found!")
                best_model_summary = best_model.summary

# Convert results to DataFrame and sort
results_df = pd.DataFrame(results).sort_values('rmse')

#print best params
print("Best parameters:")
print(f"LSTM Units: {best_params['units']}")
print(f"Dropout Rate: {best_params['dropout']}")
print(f"Learning Rate: {best_params['learning_rate']}")
print(f"Best RMSE: {best_rmse:.4f}")
print(best_model_summary)
# Out:
# Training with: units=50, dropout=0.2, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1571 - val_loss: 0.0540
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0494 - val_loss: 0.0222
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0287 - val_loss: 0.0183
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0261 - val_loss: 0.0166
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0209 - val_loss: 0.0184
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0234 - val_loss: 0.0161
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0214 - val_loss: 0.0160
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0210 - val_loss: 0.0161
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0196 - val_loss: 0.0160
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0213 - val_loss: 0.0162
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0198 - val_loss: 0.0166
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0212 - val_loss: 0.0161
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0251 - val_loss: 0.0161
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0211 - val_loss: 0.0159
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0221 - val_loss: 0.0166
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0226 - val_loss: 0.0165
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0201 - val_loss: 0.0160
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0187 - val_loss: 0.0160
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0221 - val_loss: 0.0166
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0230 - val_loss: 0.0159
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0177 - val_loss: 0.0162
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0201 - val_loss: 0.0159
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0196 - val_loss: 0.0161
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0189 - val_loss: 0.0172
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0188 - val_loss: 0.0162
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0237 - val_loss: 0.0175
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0188 - val_loss: 0.0161
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0201 - val_loss: 0.0169
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# New best model found!
# Training with: units=50, dropout=0.2, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.2286 - val_loss: 0.0509
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0447 - val_loss: 0.0291
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0320 - val_loss: 0.0154
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0242 - val_loss: 0.0156
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0207 - val_loss: 0.0160
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0208 - val_loss: 0.0157
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0242 - val_loss: 0.0156
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0199 - val_loss: 0.0158
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0244 - val_loss: 0.0156
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0224 - val_loss: 0.0165
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0194 - val_loss: 0.0157
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0211 - val_loss: 0.0161
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0232 - val_loss: 0.0164
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0203 - val_loss: 0.0158
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - val_loss: 0.0158
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0234 - val_loss: 0.0174
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0184 - val_loss: 0.0160
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0239 - val_loss: 0.0156
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# New best model found!
# Training with: units=50, dropout=0.3, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1501 - val_loss: 0.0563
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0526 - val_loss: 0.0221
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0310 - val_loss: 0.0160
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0265 - val_loss: 0.0156
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0263 - val_loss: 0.0156
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0215 - val_loss: 0.0156
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0234 - val_loss: 0.0157
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0201 - val_loss: 0.0162
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0225 - val_loss: 0.0156
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - val_loss: 0.0158
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - val_loss: 0.0162
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0214 - val_loss: 0.0162
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0222 - val_loss: 0.0159
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0206 - val_loss: 0.0163
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0185 - val_loss: 0.0160
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0234 - val_loss: 0.0164
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0224 - val_loss: 0.0164
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0222 - val_loss: 0.0208
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228 - val_loss: 0.0164
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0225 - val_loss: 0.0165
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x30c70a3e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x30c70a3e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# New best model found!
# Training with: units=50, dropout=0.3, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.2680 - val_loss: 0.0684
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0627 - val_loss: 0.0303
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0375 - val_loss: 0.0161
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0306 - val_loss: 0.0164
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0216 - val_loss: 0.0168
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0333 - val_loss: 0.0158
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0293 - val_loss: 0.0155
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0296 - val_loss: 0.0162
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0241 - val_loss: 0.0158
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0236 - val_loss: 0.0164
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0222 - val_loss: 0.0155
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0237 - val_loss: 0.0164
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0265 - val_loss: 0.0159
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0232 - val_loss: 0.0157
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0206 - val_loss: 0.0161
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0240 - val_loss: 0.0156
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0253 - val_loss: 0.0159
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0236 - val_loss: 0.0165
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0215 - val_loss: 0.0158
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0219 - val_loss: 0.0157
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0201 - val_loss: 0.0162
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0221 - val_loss: 0.0161
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228 - val_loss: 0.0160
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0187 - val_loss: 0.0158
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - val_loss: 0.0159
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0193 - val_loss: 0.0159
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Training with: units=75, dropout=0.2, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1547 - val_loss: 0.0182
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0335 - val_loss: 0.0184
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0307 - val_loss: 0.0160
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0224 - val_loss: 0.0167
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - val_loss: 0.0162
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - val_loss: 0.0184
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0214 - val_loss: 0.0158
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0234 - val_loss: 0.0192
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0225 - val_loss: 0.0164
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0182 - val_loss: 0.0167
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - val_loss: 0.0165
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0194 - val_loss: 0.0162
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0221 - val_loss: 0.0160
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - val_loss: 0.0168
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0185 - val_loss: 0.0159
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0236 - val_loss: 0.0162
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0216 - val_loss: 0.0215
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0244 - val_loss: 0.0182
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0264 - val_loss: 0.0181
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0196 - val_loss: 0.0161
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0218 - val_loss: 0.0186
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - val_loss: 0.0159
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Training with: units=75, dropout=0.2, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1271 - val_loss: 0.0364
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0346 - val_loss: 0.0202
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0298 - val_loss: 0.0157
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0247 - val_loss: 0.0163
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0211 - val_loss: 0.0160
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0223 - val_loss: 0.0161
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0219 - val_loss: 0.0158
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0234 - val_loss: 0.0161
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - val_loss: 0.0159
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0255 - val_loss: 0.0161
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0195 - val_loss: 0.0165
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206 - val_loss: 0.0162
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0236 - val_loss: 0.0163
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0205 - val_loss: 0.0163
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0201 - val_loss: 0.0165
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206 - val_loss: 0.0164
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0182 - val_loss: 0.0173
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0188 - val_loss: 0.0163
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Training with: units=75, dropout=0.3, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1543 - val_loss: 0.0159
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0292 - val_loss: 0.0169
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0220 - val_loss: 0.0162
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0255 - val_loss: 0.0161
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0234 - val_loss: 0.0164
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0217 - val_loss: 0.0165
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0205 - val_loss: 0.0162
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0225 - val_loss: 0.0165
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0244 - val_loss: 0.0175
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0239 - val_loss: 0.0167
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0215 - val_loss: 0.0169
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0195 - val_loss: 0.0166
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0197 - val_loss: 0.0165
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0185 - val_loss: 0.0165
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0188 - val_loss: 0.0173
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0221 - val_loss: 0.0161
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Training with: units=75, dropout=0.3, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.2668 - val_loss: 0.0281
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0547 - val_loss: 0.0162
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0302 - val_loss: 0.0207
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0268 - val_loss: 0.0169
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0253 - val_loss: 0.0161
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0254 - val_loss: 0.0180
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0265 - val_loss: 0.0167
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0246 - val_loss: 0.0164
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0200 - val_loss: 0.0166
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0252 - val_loss: 0.0171
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0234 - val_loss: 0.0164
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0220 - val_loss: 0.0163
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.0166
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0233 - val_loss: 0.0166
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0238 - val_loss: 0.0165
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0204 - val_loss: 0.0164
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0213 - val_loss: 0.0164
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - val_loss: 0.0166
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0240 - val_loss: 0.0164
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0232 - val_loss: 0.0161
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Training with: units=100, dropout=0.2, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0879 - val_loss: 0.0311
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0289 - val_loss: 0.0174
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0225 - val_loss: 0.0177
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0263 - val_loss: 0.0167
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0223 - val_loss: 0.0184
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0214 - val_loss: 0.0167
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0205 - val_loss: 0.0167
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0190 - val_loss: 0.0170
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0223 - val_loss: 0.0182
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0227 - val_loss: 0.0179
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0213 - val_loss: 0.0194
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0235 - val_loss: 0.0172
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0204 - val_loss: 0.0179
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0221 - val_loss: 0.0166
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0205 - val_loss: 0.0168
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0207 - val_loss: 0.0165
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0239 - val_loss: 0.0174
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0228 - val_loss: 0.0174
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0170
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0169
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0248 - val_loss: 0.0279
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0249 - val_loss: 0.0193
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0212 - val_loss: 0.0185
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0163
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0192 - val_loss: 0.0163
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0216 - val_loss: 0.0219
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0229 - val_loss: 0.0184
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0205 - val_loss: 0.0181
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165 - val_loss: 0.0186
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0227 - val_loss: 0.0195
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0290 - val_loss: 0.0184
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0188 - val_loss: 0.0166
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0200 - val_loss: 0.0167
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0181 - val_loss: 0.0165
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0173
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0181 - val_loss: 0.0163
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0235 - val_loss: 0.0174
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0221 - val_loss: 0.0173
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0189 - val_loss: 0.0164
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0176 - val_loss: 0.0184
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Training with: units=100, dropout=0.2, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1926 - val_loss: 0.0501
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0399 - val_loss: 0.0246
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0355 - val_loss: 0.0163
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - val_loss: 0.0165
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0199 - val_loss: 0.0159
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0216 - val_loss: 0.0165
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0218 - val_loss: 0.0159
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0194 - val_loss: 0.0167
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0248 - val_loss: 0.0162
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0201 - val_loss: 0.0177
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0208 - val_loss: 0.0160
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0214 - val_loss: 0.0162
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0160
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0201 - val_loss: 0.0166
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0206 - val_loss: 0.0161
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0194 - val_loss: 0.0174
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0212 - val_loss: 0.0162
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0198 - val_loss: 0.0165
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0221 - val_loss: 0.0164
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0177 - val_loss: 0.0163
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0194 - val_loss: 0.0170
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0238 - val_loss: 0.0164
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Training with: units=100, dropout=0.3, learning_rate=0.001
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1177 - val_loss: 0.0186
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0287 - val_loss: 0.0175
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0271 - val_loss: 0.0182
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0225 - val_loss: 0.0164
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218 - val_loss: 0.0167
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0248 - val_loss: 0.0198
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0217 - val_loss: 0.0163
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0192 - val_loss: 0.0191
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0248 - val_loss: 0.0168
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0195 - val_loss: 0.0170
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0248 - val_loss: 0.0218
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0236 - val_loss: 0.0172
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0255 - val_loss: 0.0164
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0245 - val_loss: 0.0191
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0226 - val_loss: 0.0168
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0217 - val_loss: 0.0173
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0192 - val_loss: 0.0213
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0266 - val_loss: 0.0168
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0208 - val_loss: 0.0174
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0218 - val_loss: 0.0181
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0248 - val_loss: 0.0259
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Training with: units=100, dropout=0.3, learning_rate=0.0005
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1623 - val_loss: 0.0383
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0358 - val_loss: 0.0204
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0242 - val_loss: 0.0177
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0290 - val_loss: 0.0166
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0251 - val_loss: 0.0167
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0249 - val_loss: 0.0163
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0214 - val_loss: 0.0166
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0233 - val_loss: 0.0163
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0213 - val_loss: 0.0180
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0236 - val_loss: 0.0163
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0223 - val_loss: 0.0170
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0203 - val_loss: 0.0161
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0223 - val_loss: 0.0160
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0192 - val_loss: 0.0161
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0216 - val_loss: 0.0163
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0229 - val_loss: 0.0164
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0220 - val_loss: 0.0167
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0188 - val_loss: 0.0165
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.0174
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0226 - val_loss: 0.0163
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0201 - val_loss: 0.0166
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0179 - val_loss: 0.0168
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0220 - val_loss: 0.0163
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0213 - val_loss: 0.0163
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0212 - val_loss: 0.0172
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0162
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0162
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0244 - val_loss: 0.0164
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Best parameters:
# LSTM Units: 50
# Dropout Rate: 0.3
# Learning Rate: 0.001
# Best RMSE: 6.8057
# <bound method Model.summary of <Sequential name=sequential_2, built=True>>

# %%
from tensorflow.keras.models import Sequential
#train and test using best model
train_data = scaled_data.loc[:'2018-01-01']
test_data = scaled_data.loc['2018-02-01':]
seq_length = 12  # 12 months of history
X_train, y_train = [], []
for i in range(len(train_data) - seq_length):
    X_train.append(train_data.iloc[i:(i + seq_length)].values)
    y_train.append(train_data.iloc[i + seq_length]['wheat_price_logret_future'])
X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = [], []
for i in range(len(test_data) - seq_length):
    X_test.append(test_data.iloc[i:(i + seq_length)].values)
    y_test.append(test_data.iloc[i + seq_length]['wheat_price_logret_future'])
X_test, y_test = np.array(X_test), np.array(y_test)

#Build LSTM model
lstm_model = Sequential()
lstm_model.add(keras.layers.LSTM(units, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
lstm_model.add(keras.layers.LSTM(units, return_sequences=False))
lstm_model.add(keras.layers.Dense(128,activation='relu'))
lstm_model.add(keras.layers.Dropout(dropout))
lstm_model.add(keras.layers.Dense(1))
lstm_model.compile(optimizer=Adam(learning_rate=lr), loss='mse')

history = lstm_model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    shuffle=False
)
lstm_predictions_scaled = lstm_model.predict(X_test)

#get pred vals
dummy = np.zeros((len(lstm_predictions_scaled), len(lstm_data.columns)))
dummy[:, -1] = lstm_predictions_scaled.flatten()
inverse_dummy = scaler.inverse_transform(dummy)
lstm_predictions = inverse_dummy[:, -1]

#Create a Series with the predictions
lstm_forecast_series = pd.Series(
    lstm_predictions, 
    index=test_data.index[seq_length:],
    name='LSTM Forecast'
)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1383 - val_loss: 0.0470
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0416 - val_loss: 0.0208
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0262 - val_loss: 0.0168
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0240 - val_loss: 0.0162
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0193 - val_loss: 0.0164
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0192 - val_loss: 0.0165
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0189 - val_loss: 0.0166
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0184 - val_loss: 0.0169
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0194 - val_loss: 0.0168
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0184 - val_loss: 0.0168
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0187 - val_loss: 0.0177
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0197 - val_loss: 0.0171
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0162 - val_loss: 0.0175
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0183 - val_loss: 0.0174
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0221 - val_loss: 0.0172
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0178 - val_loss: 0.0172
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0159 - val_loss: 0.0175
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0200 - val_loss: 0.0175
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0184 - val_loss: 0.0181
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0190 - val_loss: 0.0175
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0176 - val_loss: 0.0180
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0182
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0200 - val_loss: 0.0183
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0160 - val_loss: 0.0188
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0210 - val_loss: 0.0179
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0203 - val_loss: 0.0187
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0172 - val_loss: 0.0176
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0203 - val_loss: 0.0180
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0182 - val_loss: 0.0180
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0163 - val_loss: 0.0182
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0178 - val_loss: 0.0183
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0175 - val_loss: 0.0181
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0203 - val_loss: 0.0187
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0183 - val_loss: 0.0176
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0166 - val_loss: 0.0177
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0174 - val_loss: 0.0178
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187 - val_loss: 0.0202
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0170 - val_loss: 0.0180
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0181 - val_loss: 0.0179
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0199 - val_loss: 0.0177
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0180 - val_loss: 0.0186
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0190 - val_loss: 0.0179
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0193 - val_loss: 0.0181
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0178 - val_loss: 0.0198
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0184 - val_loss: 0.0176
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0194 - val_loss: 0.0191
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0172 - val_loss: 0.0184
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0167 - val_loss: 0.0177
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0192 - val_loss: 0.0246
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0199 - val_loss: 0.0172
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0188 - val_loss: 0.0175
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0206 - val_loss: 0.0213
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0197 - val_loss: 0.0175
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0174 - val_loss: 0.0187
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0174 - val_loss: 0.0187
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0206 - val_loss: 0.0179
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0163 - val_loss: 0.0212
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0212 - val_loss: 0.0172
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0195 - val_loss: 0.0184
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0182 - val_loss: 0.0185
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0162 - val_loss: 0.0176
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0172 - val_loss: 0.0180
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0153 - val_loss: 0.0180
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0156 - val_loss: 0.0173
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0192 - val_loss: 0.0191
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0186 - val_loss: 0.0166
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0168 - val_loss: 0.0186
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0186 - val_loss: 0.0172
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0178 - val_loss: 0.0176
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0164 - val_loss: 0.0184
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0156 - val_loss: 0.0170
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0169 - val_loss: 0.0203
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0204 - val_loss: 0.0197
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0150 - val_loss: 0.0169
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165 - val_loss: 0.0170
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0151 - val_loss: 0.0170
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0192 - val_loss: 0.0159
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0157 - val_loss: 0.0188
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186 - val_loss: 0.0173
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0204 - val_loss: 0.0222
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0205 - val_loss: 0.0168
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165 - val_loss: 0.0181
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0138 - val_loss: 0.0181
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165 - val_loss: 0.0178
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0166 - val_loss: 0.0173
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0158 - val_loss: 0.0174
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0162 - val_loss: 0.0166
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0174 - val_loss: 0.0183
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175 - val_loss: 0.0174
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
#plot predictions vs actual
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(lstm_forecast_series.index, lstm_forecast_series, label="Forecast", color="red", linestyle="dashed")

#format
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - LSTM Model")
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
#prep VAR model
var_features = ['wheat_price_logret', 'corn_price_logret', 'fertilizer_idx_logret', 
               'commodity_imp_idx_logret', 'commodity_exp_idx_logret', 
               'crude_oil_price_logret', 'wheat_price_logret_future']
var_data = logret_df[var_features].copy()

# Split into train/test sets
var_train = var_data.loc[:'2018-01-01']
var_test = var_data.loc['2018-02-01':]

#Fit VAR model
var_model = VAR(var_train)
#Select order based on AIC
var_results = var_model.select_order(maxlags=12)
var_order = var_results.selected_orders['aic']
print(f"Selected VAR order based on AIC: {var_order}")

#Fit model with best order
fitted_var_model = var_model.fit(var_order)
print(fitted_var_model.summary())

#Forecast
var_forecast_input = var_train.values[-var_order:]
var_forecast_steps = len(var_test)
var_forecast = fitted_var_model.forecast(y=var_forecast_input, steps=var_forecast_steps)

# Extract wheat price predictions
var_wheat_predictions = var_forecast[:, -1]

# Create a Series with the predictions
var_forecast_series = pd.Series(
    var_wheat_predictions, 
    index=var_test.index[:var_forecast_steps],
    name='VAR Forecast'
)
# Out:
# Selected VAR order based on AIC: 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 12, May, 2025
# Time:                     11:39:23
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                   -54.8198
# Nobs:                     335.000    HQIC:                  -55.2032
# Log likelihood:           6017.71    FPE:                8.22570e-25
# AIC:                     -55.4574    Det(Omega_mle):     6.97313e-25
# --------------------------------------------------------------------
# Results for equation wheat_price_logret
# =====================================================================================================
#                                   coefficient       std. error                 t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                0.000000         0.000000                  0.011           0.992
# L1.wheat_price_logret                0.000000         0.000000                  7.967           0.000
# L1.corn_price_logret                -0.000000         0.000000                -11.129           0.000
# L1.fertilizer_idx_logret            -0.000000         0.000000                 -1.991           0.046
# L1.commodity_imp_idx_logret          0.000000         0.000000                  2.453           0.014
# L1.commodity_exp_idx_logret         -0.000000         0.000000                 -1.356           0.175
# L1.crude_oil_price_logret           -0.000000         0.000000                 -1.060           0.289
# L1.wheat_price_logret_future         1.000000         0.000000  19550633830492248.000           0.000
# =====================================================================================================
#
# Results for equation corn_price_logret
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.054973         0.257401            0.214           0.831
# L1.wheat_price_logret               -0.026125         0.046318           -0.564           0.573
# L1.corn_price_logret                 0.222739         0.056138            3.968           0.000
# L1.fertilizer_idx_logret             0.128924         0.074166            1.738           0.082
# L1.commodity_imp_idx_logret         -0.185125         0.420531           -0.440           0.660
# L1.commodity_exp_idx_logret          0.476609         0.682129            0.699           0.485
# L1.crude_oil_price_logret           -0.064979         0.047025           -1.382           0.167
# L1.wheat_price_logret_future         0.446971         0.039708           11.256           0.000
# ===============================================================================================
#
# Results for equation fertilizer_idx_logret
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.075291         0.154797            0.486           0.627
# L1.wheat_price_logret                0.009636         0.027855            0.346           0.729
# L1.corn_price_logret                 0.012211         0.033761            0.362           0.718
# L1.fertilizer_idx_logret             0.549064         0.044603           12.310           0.000
# L1.commodity_imp_idx_logret          1.061372         0.252901            4.197           0.000
# L1.commodity_exp_idx_logret         -0.629986         0.410222           -1.536           0.125
# L1.crude_oil_price_logret           -0.035075         0.028280           -1.240           0.215
# L1.wheat_price_logret_future        -0.001046         0.023880           -0.044           0.965
# ===============================================================================================
#
# Results for equation commodity_imp_idx_logret
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.047752         0.051492            0.927           0.354
# L1.wheat_price_logret               -0.000178         0.009266           -0.019           0.985
# L1.corn_price_logret                 0.025645         0.011230            2.284           0.022
# L1.fertilizer_idx_logret            -0.022334         0.014837           -1.505           0.132
# L1.commodity_imp_idx_logret          0.358625         0.084125            4.263           0.000
# L1.commodity_exp_idx_logret          0.055318         0.136456            0.405           0.685
# L1.crude_oil_price_logret            0.041954         0.009407            4.460           0.000
# L1.wheat_price_logret_future         0.012818         0.007943            1.614           0.107
# ===============================================================================================
#
# Results for equation commodity_exp_idx_logret
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.060270         0.025997            2.318           0.020
# L1.wheat_price_logret                0.005626         0.004678            1.203           0.229
# L1.corn_price_logret                 0.024271         0.005670            4.281           0.000
# L1.fertilizer_idx_logret             0.002678         0.007491            0.357           0.721
# L1.commodity_imp_idx_logret          0.162896         0.042473            3.835           0.000
# L1.commodity_exp_idx_logret          0.067153         0.068894            0.975           0.330
# L1.crude_oil_price_logret            0.004396         0.004750            0.926           0.355
# L1.wheat_price_logret_future         0.014764         0.004011            3.681           0.000
# ===============================================================================================
#
# Results for equation crude_oil_price_logret
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.223814         0.451167            0.496           0.620
# L1.wheat_price_logret               -0.119590         0.081186           -1.473           0.141
# L1.corn_price_logret                 0.110875         0.098398            1.127           0.260
# L1.fertilizer_idx_logret            -0.174055         0.129998           -1.339           0.181
# L1.commodity_imp_idx_logret          0.774577         0.737099            1.051           0.293
# L1.commodity_exp_idx_logret         -0.102322         1.195623           -0.086           0.932
# L1.crude_oil_price_logret            0.227386         0.082425            2.759           0.006
# L1.wheat_price_logret_future         0.100144         0.069600            1.439           0.150
# ===============================================================================================
#
# Results for equation wheat_price_logret_future
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.035537         0.363079            0.098           0.922
# L1.wheat_price_logret               -0.045027         0.065335           -0.689           0.491
# L1.corn_price_logret                 0.011159         0.079186            0.141           0.888
# L1.fertilizer_idx_logret             0.015702         0.104616            0.150           0.881
# L1.commodity_imp_idx_logret          0.356735         0.593184            0.601           0.548
# L1.commodity_exp_idx_logret         -0.557351         0.962183           -0.579           0.562
# L1.crude_oil_price_logret            0.001248         0.066332            0.019           0.985
# L1.wheat_price_logret_future         0.247266         0.056011            4.415           0.000
# ===============================================================================================
#
# Correlation matrix of residuals
#                              wheat_price_logret  corn_price_logret  fertilizer_idx_logret  commodity_imp_idx_logret  commodity_exp_idx_logret  crude_oil_price_logret  wheat_price_logret_future
# wheat_price_logret                     1.000000           0.004225              -0.001554                  0.002150                 -0.000638                0.001467                  -0.004711
# corn_price_logret                      0.004225           1.000000               0.117189                  0.144113                  0.307766                0.070452                  -0.024736
# fertilizer_idx_logret                 -0.001554           0.117189               1.000000                  0.164977                  0.160618                0.117453                   0.054713
# commodity_imp_idx_logret               0.002150           0.144113               0.164977                  1.000000                  0.591307                0.787514                   0.034064
# commodity_exp_idx_logret              -0.000638           0.307766               0.160618                  0.591307                  1.000000                0.424302                  -0.087610
# crude_oil_price_logret                 0.001467           0.070452               0.117453                  0.787514                  0.424302                1.000000                   0.034287
# wheat_price_logret_future             -0.004711          -0.024736               0.054713                  0.034064                 -0.087610                0.034287                   1.000000

# %%
#plot predictions and actual values
plt.figure(figsize=(30, 6))
plt.plot(logret_df_train_data.index, logret_df_train_data["wheat_price_logret_future"], label="In-Sample Data", color="black", linewidth=1)
plt.plot(logret_df_test_data.index, logret_df_test_data["wheat_price_logret_future"], label="Actual Out-of-Sample", color="green", linestyle="solid")
plt.plot(var_forecast_series.index, var_forecast_series, label="Forecast", color="red", linestyle="dashed")

# Formatting
plt.xlabel("Time")
plt.ylabel("logret")
plt.title("Wheat Price Log Return Prediction - VAR Model")
plt.legend()
plt.grid(True)
plt.savefig('../Visualizations/VAR_Predictions.png')
plt.show()

# %%
#calculate mse, rmse, mae for LSTM and VAR models

#LSTM
lstm_rmse = np.sqrt(mean_squared_error(
    test_data.iloc[seq_length:]['wheat_price_logret_future'], 
    lstm_forecast_series
))
lstm_mae = mean_absolute_error(
    test_data.iloc[seq_length:]['wheat_price_logret_future'], 
    lstm_forecast_series
)
lstm_mse =mean_squared_error(
    test_data.iloc[seq_length:]['wheat_price_logret_future'], 
    lstm_forecast_series
)
#VAR
var_rmse = np.sqrt(mean_squared_error(
    var_test['wheat_price_logret_future'][:var_forecast_steps], 
    var_forecast_series
))
var_mae = mean_absolute_error(
    var_test['wheat_price_logret_future'][:var_forecast_steps], 
    var_forecast_series
)
var_mse=mean_squared_error(
    var_test['wheat_price_logret_future'][:var_forecast_steps], 
    var_forecast_series
)

# %%
#compare metrics between models
actual_values = logret_df_test_data["wheat_price_logret_future"]
forecasts = {
    'AutoReg': forecast_result_mean,
    'ARIMA': arima_forecast_result_mean,
    'SARIMAX': sarimax_forecast_result_mean,
    'Decision Tree': dt_forecast_series,
    'XGBoost': xgb_forecast_series
}

#Calculate metrics
results = []
for model_name, predicted_values in forecasts.items():
    mse = mean_squared_error(actual_values, predicted_values)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(actual_values, predicted_values)
    
    results.append({
        'Model': model_name,
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae
    })
results_df = pd.DataFrame(results).sort_values('RMSE')
new_df = pd.DataFrame([
    {'Model': 'VAR', 'MSE': var_mse, 'RMSE': var_rmse, 'MAE': var_mae},
    {'Model': 'LSTM', 'MSE': lstm_mse, 'RMSE': lstm_rmse, 'MAE': lstm_mae}
])
results_df = pd.concat([results_df, new_df], ignore_index=True).sort_values('RMSE')

#display
results_df
# Out:
#            Model        MSE      RMSE       MAE
# 6           LSTM  15.751340  3.968796  3.186625
# 0        SARIMAX  41.440526  6.437432  4.985091
# 1          ARIMA  41.878877  6.471389  4.933361
# 2        AutoReg  41.963986  6.477962  4.926149
# 3        XGBoost  44.387442  6.662390  5.238427
# 5            VAR  44.391910  6.662725  5.118948
# 4  Decision Tree  77.085196  8.779818  6.385832

# %%
#Clean plot for best ML Model
plt.figure(figsize=(12, 6), dpi=300)

#Training  
plt.plot(logret_df.index, logret_df["wheat_price_logret_future"], 
         color="lightgray", linewidth=1, label="Training Data")

# Test and predictions
plt.plot(lstm_forecast_series.index, 
         logret_df_test_data.loc[lstm_forecast_series.index, "wheat_price_logret_future"], 
         color="black", linewidth=2, label="Actual Values")
plt.plot(lstm_forecast_series.index, lstm_forecast_series, 
         color="green", linewidth=2.5, label="LSTM Forecast")
#CI
std_dev = np.std(logret_df_test_data["wheat_price_logret_future"] - lstm_forecast_series)
plt.fill_between(lstm_forecast_series.index,
                 lstm_forecast_series - 1.96*std_dev,
                 lstm_forecast_series + 1.96*std_dev,
                 alpha=0.2, color="blue", label="95% Confidence Interval")
#title and format
plt.title("LSTM Forecast of Wheat Price Log Returns", fontsize=10, pad=20)
plt.xlabel("Date", fontsize=16, labelpad=10)
plt.ylabel("Log Return (%)", fontsize=16, labelpad=10)
plt.grid(True, alpha=0.3)
plt.legend(fontsize=14, loc="upper left")
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.tight_layout()
plt.savefig('../Visualizations/LSTM_Forecast.png')
plt.show()

# %%
lstm_model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_24 (LSTM)                  │ (None, 12, 100)        │        44,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_25 (LSTM)                  │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        12,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 414,773 (1.58 MB)
#  Trainable params: 138,257 (540.07 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 276,516 (1.05 MB)

# %%
#compare model rmse and mae
models = ['LSTM', 'SARIMAX', 'ARIMA', 'AutoReg', 'VAR', 'XGBoost', 'Decision Tree'] #save model names
rmse_values = results_df['RMSE'] #save rmse
mae_values = results_df['MAE'] #save mae
plt.figure(figsize=(10, 6), dpi=300)
bar_width = 0.35
x = np.arange(len(models))

#Create bar graphs
bars1 = plt.bar(x - bar_width/2, rmse_values, bar_width, label='RMSE', 
                color='blue', edgecolor='black', linewidth=0.5)
bars2 = plt.bar(x + bar_width/2, mae_values, bar_width, label='MAE', 
                color='green', edgecolor='black', linewidth=0.5)


#Add text labels above each bar
for i, v in enumerate(rmse_values):
    plt.text(i - bar_width/2, v + 0.2, f"{v:.2f}", ha='center', fontsize=9)
    
for i, v in enumerate(mae_values):
    plt.text(i + bar_width/2, v + 0.2, f"{v:.2f}", ha='center', fontsize=9)

#Add horizontal lines showing best model 
plt.axhline(y=results_df['RMSE'][6], color='blue', linestyle='--', alpha=0.4)
plt.axhline(y=results_df['MAE'][6], color='green', linestyle='--', alpha=0.4)

# Format
plt.title('Model Performance Comparison for Wheat Price Forecasting', fontsize=14)
plt.ylabel('Error Value (lower is better)', fontsize=12)
plt.xlabel('Model', fontsize=12)
plt.xticks(x, models, fontsize=10, rotation=30, ha='right')
plt.yticks(fontsize=10)
plt.ylim(0, 10)  # Adjust as needed
plt.legend(fontsize=10, loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig('../Visualizations/Final_Model_Comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Plot LSTM errors
forecast_errors = logret_df_test_data.loc[lstm_forecast_series.index, "wheat_price_logret_future"] - lstm_forecast_series
plt.figure(figsize=(10, 6), dpi=300)

#Create histogram
plt.hist(forecast_errors, bins=20, color='blue', alpha=0.7, edgecolor='black', linewidth=0.5)

#Add a curve showing the normal distribution
mu, sigma = forecast_errors.mean(), forecast_errors.std()
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = len(forecast_errors) * 0.8 * np.exp(-(x - mu)**2 / (2 * sigma**2)) / (sigma * np.sqrt(2 * np.pi))
plt.plot(x, y, 'r-', linewidth=2, color='red')

#Add vertical lines for mean and zero
plt.axvline(x=0, color='black', linestyle='--', alpha=0.7, label='Zero Error')
plt.axvline(x=mu, color='red', linestyle='-', alpha=0.7, label=f'Mean Error: {mu:.2f}')

#Format the plot
plt.title('Distribution of LSTM Forecast Errors', fontsize=14)
plt.xlabel('Forecast Error (Actual - Predicted)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend(fontsize=10)
plt.grid(linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig('../Visualizations/LSTM_Forecast_Errors.png')
plt.show()

# %%
#save evaluation metric comparison table
results_df.to_csv('../Visualizations/results_df.csv')

# %%
#save summary statistics table
logret_sum_stats = pd.DataFrame(round(logret_df.describe(),3))
logret_sum_stats.to_csv('../Visualizations/summary_statistics.csv')
